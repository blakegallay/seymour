# %%
from newsapi import NewsApiClient

# %%
newsapi = NewsApiClient(api_key='378dfed64fb74b6d85fa7e585a0ce912')

# %%
top_headlines1 = newsapi.get_top_headlines(q='Bitcoin',
                                           category ='business',
                                          language='en',
                                          country='us')

# %%
print(top_headlines1)
# Out:
# {'status': 'ok', 'totalResults': 0, 'articles': []}

# %%
top_headlines = newsapi.get_top_headlines(q='coronavirus in florida',
                                          language='en',
                                          country='us')

# %%
print(top_headlines)
# Out:
# {'status': 'ok', 'totalResults': 1, 'articles': [{'source': {'id': None, 'name': 'CNBC'}, 'author': 'Will Feuer', 'title': 'Coronavirus deaths tick up in Florida, Texas, California, Arizona as states grapple with growing outbreaks - CNBC', 'description': '"I think in the next week the pattern of increasing deaths is going to become clear," said Larry Levitt, executive vice president for health policy at the Kaiser Family Foundation.', 'url': 'https://www.cnbc.com/2020/07/10/coronavirus-deaths-tick-up-in-florida-texas-california-arizona.html', 'urlToImage': 'https://image.cnbcfm.com/api/v1/image/106604010-1594397179281preview.jpg?v=1594397252', 'publishedAt': '2020-07-10T20:56:00Z', 'content': 'Medical staff wearing full PPE push a stretcher with a deceased patient to a car outside of the Covid-19 intensive care unit at the United Memorial Medical Center on June 30, 2020 in Houston, Texas.\r… [+8010 chars]'}]}

# %%
all_articles1 = newsapi.get_everything(q='coronavirus')

# %%
all_articles = newsapi.get_everything(q='Joe Biden')

# %%
print(all_articles)
# Out:
# {'status': 'ok', 'totalResults': 22265, 'articles': [{'source': {'id': 'the-verge', 'name': 'The Verge'}, 'author': 'Makena Kelly', 'title': 'Joe Biden doesn’t like Trump’s Twitter order, but still wants to revoke Section 230', 'description': 'Former Vice President Joe Biden still wants to repeal the pivotal internet law that provides social media companies like Facebook and Twitter with broad legal immunity over content posted by their users, a campaign spokesperson said.', 'url': 'https://www.theverge.com/2020/5/29/21274812/joe-biden-donald-trump-twitter-facebook-section-230-moderation-revoke', 'urlToImage': 'https://cdn.vox-cdn.com/thumbor/uRlBhA0r-tiVgPe6PnXALxLI6Mw=/0x345:4813x2865/fit-in/1200x630/cdn.vox-cdn.com/uploads/chorus_asset/file/20009306/1206811764.jpg.jpg', 'publishedAt': '2020-05-29T17:50:17Z', 'content': 'The campaign said his position hasnt changed\r\nPhoto by Drew Angerer/Getty Images\r\nFormer Vice President Joe Biden still wants to repeal the pivotal internet la
# ...

# %%
print(all_articles1)
# Out:
# {'status': 'ok', 'totalResults': 407381, 'articles': [{'source': {'id': 'engadget', 'name': 'Engadget'}, 'author': 'Igor Bonifacic', 'title': "Hackers targeted the UK's coronavirus vaccine research", 'description': "On top of everything else, add cybersecurity threats to the list of things the UK's National Health Service (NHS) has had to contend with during the coronavirus pandemic. In an interview with the Cheltenham Science Festival, Jeremy Fleming, the head of the co…", 'url': 'https://www.engadget.com/hackers-target-uk-nhs-research-centers-190009137.html', 'urlToImage': 'https://o.aolcdn.com/images/dims?resize=1200%2C630&crop=1200%2C630%2C0%2C0&quality=95&image_uri=https%3A%2F%2Fs.yimg.com%2Fos%2Fcreatr-images%2F2020-06%2F31c46c10-a68c-11ea-bdff-96d6d093a36f&client=amp-blogside-v2&signature=b4e22b6fbb6dbf38e83a00f90e51d0d4857477d2', 'publishedAt': '2020-06-04T19:00:34Z', 'content': "On top of everything else, add cybersecurity threats to the list of things the UK's National Heal
# ...
